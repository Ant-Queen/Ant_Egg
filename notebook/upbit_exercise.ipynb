# %% [markdown]
# ## 업비트 API 실습

# %%
import os
import jwt  # PyJWT
import uuid
import hashlib
from urllib.parse import urlencode
import requests

# %% [markdown]
# ### 환경변수 호출

# %%
from dotenv import load_dotenv

load_dotenv()

ACCESS_KEY = os.environ["UPBIT_OPEN_API_ACCESS_KEY"]
SECRET_KEY = os.environ["UPBIT_OPEN_API_SECRET_KEY"]
SERVER_URL = os.environ["UPBIT_OPEN_API_SERVER_URL"]
SERVER_URL
# Out:
# 'https://api.upbit.com'

# %% [markdown]
# os.environ을 조회 해 보았을때 .env에서 추가한 변수들이 정상적으로 추가되어 있는지 확인해보자
# 만약 정상적으로 로딩이 안된다면 아래 명령어로 .env 파일을 로딩해보자
# `%dotenv {.env파일의 절대 또는 상대경로}/.env`

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\gorlt\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_14488_JPNMJKJDULDVUCLC',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-AJ0SU3B',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\gorlt',
#         'JPY_INTERRUPT_EVENT': '976',
#         'LOCALAPPDATA': 'C:\\Users\\gorlt\\AppData\\Local',
#         'LOGONSERVER': '\\\\DESKTOP-AJ0SU3B',
#         'NUMBER_OF_PROCESSORS': '8',
#         'ONEDRIVE': 'C:\\Users\\gorlt\\OneDrive',
#         'ONEDRIVECONSUMER': 'C:\\Users\\gorlt\\OneDrive',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OS': 'Windows_NT',
#         'PATH': 'c:\\Users\\gorlt\\3D Objects\\Ant_Egg\\venv\\Scripts;C:\\Users\\gorlt\\3D Objects\\Ant_Egg\\venv\\Scripts;C:\\Users\\gorlt\\AppData\\Roaming\\Python\\Python310\\Scripts;C:\\Program Files\\Python310\\Scripts\\;C:\\Program Files\\Python310\\;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files\\Microsoft VS Code\\bin;C:\\Program Files\\Git\\cmd;C:\\Users\\gorlt\\AppData\\Local\\Microsoft\\WindowsApps',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC;.PY;.PYW',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 142 Stepping 12, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': '8e0c',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PROMPT': '(venv) $P$G',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\Windows\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHONUNBUFFERED': '1',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\Windows',
#         'TEMP': 'C:\\Users\\gorlt\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\gorlt\\AppData\\Local\\Temp',
#         'UPBIT_OPEN_API_ACCESS_KEY': '1V1Z9elBb4C0YIrdEsMITvSboNvnN94z9TpUOroj',
#         'UPBIT_OPEN_API_SECRET_KEY': 'acGDraIPOx9TaDuH7YZgMnDxhQKlSDpqPdEUDNwC',
#         'UPBIT_OPEN_API_SERVER_URL': 'https://api.upbit.com',
#         'USERDOMAIN': 'DESKTOP-AJ0SU3B',
#         'USERDOMAIN_ROAMINGPROFILE': 'DESKTOP-AJ0SU3B',
#         'USERNAME': 'gorlt',
#         'USERPROFILE': 'C:\\Users\\gorlt',
#         'VIRTUAL_ENV': 'C:\\Users\\gorlt\\3D Objects\\Ant_Egg\\venv',
#         'VIRTUAL_ENV_PROMPT': '(venv) ',
#         'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\gorlt\\AppData\\Roaming\\Code\\CachedData\\b7886d7461186a5eac768481578c1d7ca80e2d21',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': 'C:\\Program Files\\Microsoft VS Code',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '\\\\.\\pipe\\77be3cb5e6e3399c79d9ae826c4314e0-1.77.1-main-sock',
#         'VSCODE_NLS_CONFIG': '{"locale":"ko","osLocale":"ko","availableLanguages":{"*":"ko"},"_languagePackId":"4b84e04059e62852946a97c704892411.ko","_translationsConfigFile":"C:\\\\Users\\\\gorlt\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\4b84e04059e62852946a97c704892411.ko\\\\tcf.json","_cacheRoot":"C:\\\\Users\\\\gorlt\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\4b84e04059e62852946a97c704892411.ko","_resolvedLanguagePackCoreLocation":"C:\\\\Users\\\\gorlt\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\4b84e04059e62852946a97c704892411.ko\\\\b7886d7461186a5eac768481578c1d7ca80e2d21","_corruptedFile":"C:\\\\Users\\\\gorlt\\\\AppData\\\\Roaming\\\\Code\\\\clp\\\\4b84e04059e62852946a97c704892411.ko\\\\corrupted.info","_languagePackSupport":true}',
#         'VSCODE_PID': '14488',
#         'WINDIR': 'C:\\Windows',
#         '_OLD_VIRTUAL_PATH': 'C:\\Users\\gorlt\\AppData\\Roaming\\Python\\Python310\\Scripts;C:\\Program Files\\Python310\\Scripts\\;C:\\Program Files\\Python310\\;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files\\Microsoft VS Code\\bin;C:\\Program Files\\Git\\cmd;C:\\Users\\gorlt\\AppData\\Local\\Microsoft\\WindowsApps',
#         '_OLD_VIRTUAL_PROMPT': '$P$G',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %% [markdown]
# ### 토큰 만들기

# %%
def create_token(query=None):
    """API에 사용될 토큰을 생성"""
    if query is None:
        print("Start create token without query")
        payload = {
            "access_key": ACCESS_KEY,
            "nonce": str(uuid.uuid4()),
        }

        jwt_token = jwt.encode(payload, SECRET_KEY)
        authorization_token = "Bearer {}".format(jwt_token)
        return authorization_token

    # query는 dict 타입입니다.
    print("Start create token without query")
    print(query)
    m = hashlib.sha512()
    m.update(urlencode(query).encode())
    print("url encoded_query")
    print(urlencode(query).encode())
    query_hash = m.hexdigest()

    print("hash of encoded_query")
    print(query_hash)

    payload = {
        "access_key": ACCESS_KEY,
        "nonce": str(uuid.uuid4()),
        "query_hash": query_hash,
        "query_hash_alg": "SHA512",
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorization_token = "Bearer {}".format(jwt_token)
    return authorization_token

# %% [markdown]
# ### 파라미터 없이 토큰 생성

# %%
create_token()
# Out:
# Start create token without query
# 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3Nfa2V5IjoiMVYxWjllbEJiNEMwWUlyZEVzTUlUdlNib052bk45NHo5VHBVT3JvaiIsIm5vbmNlIjoiN2VlNDhhNGYtZjQ5Ny00MjBmLTgxYmYtYWU5ZDNmMTEwMjZlIn0.kb-4quK-WQ8-_mdOsyMKF52AEVi_-rOC0JJ4TZzgc3o'

# %% [markdown]
# ### 파라미터가 포함된 토큰 생성

# %%
create_token({'market': 'KRW-BTC', 'side': 'bid', 'price': '10000', 'ord_type': 'price'})
# Out:
# Start create token without query
# {'market': 'KRW-BTC', 'side': 'bid', 'price': '10000', 'ord_type': 'price'}
# url encoded_query
# b'market=KRW-BTC&side=bid&price=10000&ord_type=price'
# hash of encoded_query
# 5a62dae6bfcaf9d69ae615ce7ecee097dcf4a2f4fa751a75af5f88905740c2ad8813c153bb383a3337a03aac634efdf950b846aa963448628226c027c793422c
# 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..--xw4CjC4B5fAY-G9k3wrhUtgTu-IZMflARszuY_sGc'

# %% [markdown]
# ### 계좌 정보 조회

# %%
def query_account():
    token = create_token()
    headers = {"Authorization": token}

    res = requests.get(SERVER_URL + "/v1/accounts", headers=headers)
    return res.json()

# %%
query_account()
# Out:
# Start create token without query
# [{'currency': 'KRW',
#   'balance': '99982.60609105',
#   'locked': '0',
#   'avg_buy_price': '0',
#   'avg_buy_price_modified': True,
#   'unit_currency': 'KRW'}]

# %% [markdown]
# ### 주문하기

# %%
def send_order(query):
    query_string = urlencode(query).encode()
   
    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': ACCESS_KEY,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}
    res = requests.post(SERVER_URL + "/v1/orders", params=query_string, headers=headers)
    return res.json()

# %% [markdown]
# ### 시장 가격 매수 주문하기

# %%
query = {
    'market': 'KRW-BTC',
    'side': 'bid',
    'price': '5000',
    'ord_type': 'price'
}
send_order(query)
# Out:
# {'uuid': 'd260840a-3e5e-4a91-a259-8bbc55ec42f8',
#  'side': 'bid',
#  'ord_type': 'price',
#  'price': '5000',
#  'state': 'wait',
#  'market': 'KRW-BTC',
#  'created_at': '2023-04-14T15:06:36.852052+09:00',
#  'reserved_fee': '2.5',
#  'remaining_fee': '2.5',
#  'paid_fee': '0',
#  'locked': '5002.5',
#  'executed_volume': '0',
#  'trades_count': 0}

# %% [markdown]
# ### 시장 가격 매도 주문하기

# %%
query = {
    'market': 'KRW-BTC',
    'side': 'ask',
    'volume': '0.0002',
    'ord_type': 'market'
}
send_order(query)
# Out:
# {'error': {'name': 'insufficient_funds_ask',
#   'message': '주문가능한 금액(BTC)이 부족합니다.'}}

# %% [markdown]
# ### 고정 가격 매수 주문하기

# %%
query = {
    'market': 'KRW-BTC',
    'side': 'bid',
    'price': '40068000',
    'volume': '0.0002',
    'ord_type': 'limit'
}
send_order(query)
# Out:
# {'uuid': '45191971-d6b4-4189-a18d-d5ae015875d6',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '40068000',
#  'state': 'wait',
#  'market': 'KRW-BTC',
#  'created_at': '2023-04-14T15:07:41.315837+09:00',
#  'volume': '0.0002',
#  'remaining_volume': '0.0002',
#  'reserved_fee': '4.0068',
#  'remaining_fee': '4.0068',
#  'paid_fee': '0',
#  'locked': '8017.6068',
#  'executed_volume': '0',
#  'trades_count': 0}

# %% [markdown]
# ### 고정 가격 매도 주문하기

# %%
query = {
    'market': 'KRW-BTC',
    'side': 'ask',
    'price': '40076000',
    'volume': '0.00032470',
    'ord_type': 'limit'
}
send_order(query)
# Out:
# {'uuid': '620dc225-7bfc-45dd-b508-07817ad40da4',
#  'side': 'ask',
#  'ord_type': 'limit',
#  'price': '40076000',
#  'state': 'wait',
#  'market': 'KRW-BTC',
#  'created_at': '2023-04-14T15:09:17.222971+09:00',
#  'volume': '0.0003247',
#  'remaining_volume': '0.0003247',
#  'reserved_fee': '0',
#  'remaining_fee': '0',
#  'paid_fee': '0',
#  'locked': '0.0003247',
#  'executed_volume': '0',
#  'trades_count': 0}

# %% [markdown]
# ### 주문조회

# %%
def query_order_list(is_done_state=False):
    query_states = ["wait", "watch"]
    if is_done_state:
        query_states = ["done", "cancel"]

    states_query_string = '&'.join(["states[]={}".format(state) for state in query_states])
    query_string = states_query_string.encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': ACCESS_KEY,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.get(SERVER_URL + "/v1/orders", params=query_string, headers=headers)

    return res.json()

# %% [markdown]
# ### 대기 중인 주문 조회

# %%
query_order_list()
# Out:
# []

# %% [markdown]
# ### 체결 된 주문 조회

# %%
query_order_list(True)
# Out:
# [{'uuid': '620dc225-7bfc-45dd-b508-07817ad40da4',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '40076000',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2023-04-14T15:09:17+09:00',
#   'volume': '0.0003247',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '6.5063386',
#   'locked': '0',
#   'executed_volume': '0.0003247',
#   'trades_count': 1},
#  {'uuid': '95c4049c-d079-432c-acda-59ef2484b7b0',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '40075000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-04-14T15:08:32+09:00',
#   'volume': '0.0003247',
#   'remaining_volume': '0.0003247',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '0.0003247',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '45191971-d6b4-4189-a18d-d5ae015875d6',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '40068000',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2023-04-14T15:07:41+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0',
#   'reserved_fee': '4.0068',
#   'remaining_fee': '0',
#   'paid_fee': '4.0068',
#   'locked': '0',
#   'executed_volume': '0.0002',
#   'trades_count': 1},
#  {'uuid': 'd260840a-3e5e-4a91-a259-8bbc55ec42f8',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '5000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-04-14T15:06:37+09:00',
#   'reserved_fee': '2.5',
#   'remaining_fee': '0.0001391',
#   'paid_fee': '2.4998609',
#   'locked': '0.2783391',
#   'executed_volume': '0.0001247',
#   'trades_count': 1},
#  {'uuid': 'eef236ed-9a5d-4833-bb15-5841a5f0a08d',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '35000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-23T11:06:37+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '3.5',
#   'remaining_fee': '3.5',
#   'paid_fee': '0',
#   'locked': '7003.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '2495908e-6295-4fb0-8733-5fb22000c8f8',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '36319000',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-23T10:38:33+09:00',
#   'volume': '0.0002753',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '4.99931035',
#   'locked': '0',
#   'executed_volume': '0.0002753',
#   'trades_count': 1},
#  {'uuid': 'a53d1135-9061-44f1-980a-dfe0dd24a766',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '39760000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-23T10:35:45+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '0',
#   'locked': '0.0002',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'ab66a479-cf5a-48e2-8335-3a820fbe44f1',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '38760000',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-23T10:35:44+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0',
#   'reserved_fee': '3.876',
#   'remaining_fee': '0.2436',
#   'paid_fee': '3.6324',
#   'locked': '487.4436',
#   'executed_volume': '0.0002',
#   'trades_count': 1},
#  {'uuid': 'a9f493a3-a7a3-4b2c-bb13-56f6a44651c7',
#   'side': 'ask',
#   'ord_type': 'market',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-23T10:35:44+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '3.632',
#   'locked': '0',
#   'executed_volume': '0.0002',
#   'trades_count': 1},
#  {'uuid': '09ffb38f-8d6a-42cf-b24a-0d9060ce0fb3',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '10000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-23T10:35:44+09:00',
#   'reserved_fee': '5',
#   'remaining_fee': '0.0000014',
#   'paid_fee': '4.9999986',
#   'locked': '0.0028014',
#   'executed_volume': '0.0002753',
#   'trades_count': 1},
#  {'uuid': '7ff3a8ce-f31a-4490-bce9-bcfca7a3a270',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-06T22:00:01+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '11de9b44-a157-4b33-94e0-a2a71ac2fa88',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-06T21:59:05+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '82250a20-89fa-45c6-bd02-68e9051dbcfb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-06T21:58:22+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '91dc7682-a40b-47ae-a352-95d894731bdc',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-06T21:57:18+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'bfda9134-e44f-4a98-b183-879ca201bd87',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-02T09:35:04+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'd4571ee0-8287-49fd-bf5a-0b745f0b8afe',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-02T09:31:21+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '56fb2af5-b582-4f9c-838b-4b57fc5c7882',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-03-02T09:30:24+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'bae86604-cb01-43c1-a861-5183e6dec9d3',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-21T13:17:09+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '5233bf32-db3e-4ddc-9ec7-b72ea8ac3fbb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-21T13:15:07+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '120a8309-4615-4e54-a88f-fb863a6bc537',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-06T14:47:46+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '04013de4-419c-479c-a114-b1215f3ca5ae',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-06T14:40:50+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'd861d28b-86d2-4f9b-bc48-8eedf56b9f69',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:06:14+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '6a33e887-0138-4496-9257-3be4c1db791c',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:05:20+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '29532950-b490-41aa-b153-3a0a95912564',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:05:10+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'a718d376-99a1-4043-a6c1-d341132fa55e',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:04:58+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '96cf909d-0b84-42b1-a36d-02b2e5baab20',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:04:47+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '5a832c82-75b8-4408-a2a6-f9a206682a5b',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:03:51+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '936f6c98-b960-47a2-8c86-1877ae0965e9',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:03:24+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '16054d50-1fdc-4895-af2b-c993e5cd3613',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:01:48+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '71f242b0-ab85-4aba-8deb-04599a937046',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:01:36+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '12109ca5-e412-4dc9-9ca4-6cdf3bb4bf70',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:01:25+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'bf329a90-af57-435b-a5ce-afc1b3dc60ec',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:01:11+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'e54c213d-fde2-40bb-b962-481a0fbbcc8d',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T02:00:48+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'aa47febd-5cd1-4c7b-b043-cbf21374c296',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T01:59:10+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '5e67a0ef-2938-4aed-86a3-975e2966cde1',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T01:45:12+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '0727dd74-121a-4f68-8a1f-c03f40a58d09',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-04T01:32:25+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '833c0a84-8d86-4ee3-a192-eec23c6a38a5',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T11:50:54+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'c1748d09-81db-431b-a7b1-2fe1433866fb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T11:31:04+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '7f0e1ff6-a992-45ee-8e36-96b2b0a45d1e',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T11:16:43+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '7d4a4a97-03c5-4188-b371-4b5fca907118',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T11:15:59+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '5e646842-ea3c-487c-a652-8a65ee7bf1fc',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T11:14:56+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '95b0c598-4c3d-4e39-9b91-853d5e0e92ce',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:38:24+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '3cd240a0-6e7f-4a90-a7bd-122b6c6016e7',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '12500000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:34:35+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '0efdd059-918b-4b2c-a449-ed654d354347',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '25000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:06:22+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'e15c8d3e-a37c-4d44-b325-3a14ed12a018',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '25000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:06:10+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '34e2de91-070f-4502-a555-288c25b87fbd',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '25000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:05:48+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'ff9f9765-d8c8-48b9-a453-98c2f52bf667',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '25000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:05:48+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '68a5759d-1324-4cb2-945c-1bc3b35d149e',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '25000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:04:36+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'c6a19c50-ec2f-4d18-9fc1-f365a1ccc255',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '25000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-03T10:03:36+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0',
#   'locked': '5002.5',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'e4c656bd-eeee-42d4-9f51-d8573aeab085',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '29615000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-02T23:00:47+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.9615',
#   'remaining_fee': '2.9615',
#   'paid_fee': '0',
#   'locked': '5925.9615',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '6d29e40d-d6ab-44e4-bcaf-27e561a4ebcb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '29615000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2023-02-02T15:21:57+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.9615',
#   'remaining_fee': '2.9615',
#   'paid_fee': '0',
#   'locked': '5925.9615',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'a8414c85-acf9-4eda-b78b-ecbfd319fbd3',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '21193000',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2022-12-28T23:25:20+09:00',
#   'volume': '0.0003',
#   'remaining_volume': '0',
#   'reserved_fee': '0',
#   'remaining_fee': '0',
#   'paid_fee': '3.17895',
#   'locked': '0',
#   'executed_volume': '0.0003',
#   'trades_count': 1},
#  {'uuid': '40e68095-6aae-439b-913f-b565bb10f374',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '21165000',
#   'state': 'done',
#   'market': 'KRW-BTC',
#   'created_at': '2022-12-28T23:17:23+09:00',
#   'volume': '0.0003',
#   'remaining_volume': '0',
#   'reserved_fee': '3.17475',
#   'remaining_fee': '0',
#   'paid_fee': '3.17475',
#   'locked': '0',
#   'executed_volume': '0.0003',
#   'trades_count': 1},
#  {'uuid': '250ac71e-adb9-464c-83d4-60864876f648',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '22210000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-11-29T12:54:13+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '4.442',
#   'remaining_fee': '4.442',
#   'paid_fee': '0',
#   'locked': '8888.442',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'df15a9cf-0f3e-448a-9565-ae8d9fb2d046',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '22200000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-11-29T12:53:45+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '4.44',
#   'remaining_fee': '4.44',
#   'paid_fee': '0',
#   'locked': '8884.44',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '70e851db-b729-44c0-9b71-e520933f1fb5',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '22005000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-11-29T12:53:23+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '4.401',
#   'remaining_fee': '4.401',
#   'paid_fee': '0',
#   'locked': '8806.401',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'dcf2d5f0-57d5-4659-926f-6d4eeecb63ae',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '22305000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-11-29T12:52:22+09:00',
#   'volume': '0.0004',
#   'remaining_volume': '0.0004',
#   'reserved_fee': '4.461',
#   'remaining_fee': '4.461',
#   'paid_fee': '0',
#   'locked': '8926.461',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': 'ec1df197-7c3e-4a7c-8721-80bae306bfad',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '22000000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-11-29T12:49:14+09:00',
#   'volume': '0.0003',
#   'remaining_volume': '0.0003',
#   'reserved_fee': '3.3',
#   'remaining_fee': '3.3',
#   'paid_fee': '0',
#   'locked': '6603.3',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '3af88c87-8bd2-4fe5-b78a-7c14350898dd',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '28230000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-10-04T13:48:37+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.823',
#   'remaining_fee': '2.823',
#   'paid_fee': '0',
#   'locked': '5648.823',
#   'executed_volume': '0',
#   'trades_count': 0},
#  {'uuid': '9a35840d-552b-427b-8f35-750786cf0765',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '28220000',
#   'state': 'cancel',
#   'market': 'KRW-BTC',
#   'created_at': '2022-10-04T13:48:04+09:00',
#   'volume': '0.0002',
#   'remaining_volume': '0.0002',
#   'reserved_fee': '2.822',
#   'remaining_fee': '2.822',
#   'paid_fee': '0',
#   'locked': '5646.822',
#   'executed_volume': '0',
#   'trades_count': 0}]

# %% [markdown]
# ### 주문 취소하기

# %%
def cancel_order(order_uuid=None):
    if order_uuid is None:
        return

    query = {
        'uuid': order_uuid,
    }
    query_string = urlencode(query).encode()

    m = hashlib.sha512()
    m.update(query_string)
    query_hash = m.hexdigest()

    payload = {
        'access_key': ACCESS_KEY,
        'nonce': str(uuid.uuid4()),
        'query_hash': query_hash,
        'query_hash_alg': 'SHA512',
    }

    jwt_token = jwt.encode(payload, SECRET_KEY)
    authorize_token = 'Bearer {}'.format(jwt_token)
    headers = {"Authorization": authorize_token}

    res = requests.delete(SERVER_URL + "/v1/order", params=query, headers=headers)

    return res.json()

# %% [markdown]
# ### UUID로 주문 최소

# %%
cancel_order('657c9b11-8d63-4db9-b8b9-14094b7992a2')
# Out:
# {'error': {'message': '주문을 찾지 못했습니다.', 'name': 'order_not_found'}}

# %% [markdown]
# ### 최근 거래 내역 조회

# %%
def query_latest_trade(market):
    """최근 거래 내역 조회
    response:
        trade_date_utc: 체결 일자(UTC 기준), String
        trade_time_utc: 체결 시각(UTC 기준), String
        timestamp: 체결 타임스탬프, Long
        trade_price: 체결 가격, Double
        trade_volume: 체결량, Double
        prev_closing_price: 전일 종가, Double
        change_price: 변화량, Double
        ask_bid: 매도/매수, String
        sequential_id: 체결 번호(Unique), Long
    """
    querystring = {
        "market": market,
        "count":"2"
    }

    response = requests.request("GET", SERVER_URL + "/v1/trades/ticks", params=querystring)

    return response.json()
query_latest_trade('KRW-BTC')
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date_utc': '2023-04-14',
#   'trade_time_utc': '06:10:32',
#   'timestamp': 1681452632874,
#   'trade_price': 40064000.0,
#   'trade_volume': 0.0057,
#   'prev_closing_price': 39911000.0,
#   'change_price': 153000.0,
#   'ask_bid': 'ASK',
#   'sequential_id': 1681452632874000},
#  {'market': 'KRW-BTC',
#   'trade_date_utc': '2023-04-14',
#   'trade_time_utc': '06:10:31',
#   'timestamp': 1681452631152,
#   'trade_price': 40063000.0,
#   'trade_volume': 0.00420765,
#   'prev_closing_price': 39911000.0,
#   'change_price': 152000.0,
#   'ask_bid': 'BID',
#   'sequential_id': 1681452631152000}]
