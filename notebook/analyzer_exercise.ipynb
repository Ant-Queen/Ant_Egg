# %% [markdown]
# ### list 두개를 합치기

# %%
list1 = [{"date_time":"2020-02-27T23:00:00",  "price":1000, "kind": 1}, 
  {"date_time":"2020-02-27T23:00:00",  "price":1000, "kind": 0},
  {"date_time":"2020-02-27T23:00:00",  "price":1000, "kind": 2}
]

list2 = [{"date_time":"2020-02-27T23:02:00",  "price":1000, "kind": 0},
  {"date_time":"2020-02-27T23:01:00",  "price":1000, "kind": 1},
  {"date_time":"2020-02-27T23:01:00",  "price":1000, "kind": 0}
]

total = list1 + list2
total
# Out:
# [{'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 1},
#  {'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 0},
#  {'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 2},
#  {'date_time': '2020-02-27T23:02:00', 'price': 1000, 'kind': 0},
#  {'date_time': '2020-02-27T23:01:00', 'price': 1000, 'kind': 1},
#  {'date_time': '2020-02-27T23:01:00', 'price': 1000, 'kind': 0}]

# %% [markdown]
# ### list를 sorted 함수를 이용해서 date_time 기준으로 정렬

# %%
from datetime import datetime
sorted_total = sorted(
  total,
  key=lambda x: datetime.strptime(x["date_time"], "%Y-%m-%dT%H:%M:%S")
)
sorted_total
# Out:
# [{'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 1},
#  {'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 0},
#  {'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 2},
#  {'date_time': '2020-02-27T23:01:00', 'price': 1000, 'kind': 1},
#  {'date_time': '2020-02-27T23:01:00', 'price': 1000, 'kind': 0},
#  {'date_time': '2020-02-27T23:02:00', 'price': 1000, 'kind': 0}]

# %% [markdown]
# ### list를 sorted함수를 이용해서 date_time과 kind를 기준으로 정렬

# %%
sorted_total = sorted(
    total,
    key=lambda x: (
        datetime.strptime(x["date_time"], "%Y-%m-%dT%H:%M:%S"),
        x["kind"],
    ),
)
sorted_total
# Out:
# [{'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 0},
#  {'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 1},
#  {'date_time': '2020-02-27T23:00:00', 'price': 1000, 'kind': 2},
#  {'date_time': '2020-02-27T23:01:00', 'price': 1000, 'kind': 0},
#  {'date_time': '2020-02-27T23:01:00', 'price': 1000, 'kind': 1},
#  {'date_time': '2020-02-27T23:02:00', 'price': 1000, 'kind': 0}]

# %% [markdown]
# ### 캔들 그래프 연습을 위한 더미 데이터

# %%
dummy_info_list = [
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:50:00',
  'opening_price': 10591000.0,
  'high_price': 10605000.0,
  'low_price': 10591000.0,
  'closing_price': 10605000.0,
  'acc_price': 116316536.37072,
  'acc_volume': 10.97288124,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:51:00',
  'opening_price': 10608000.0,
  'high_price': 10611000.0,
  'low_price': 10596000.0,
  'closing_price': 10598000.0,
  'acc_price': 132749879.7377,
  'acc_volume': 12.52234496,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:52:00',
  'opening_price': 10598000.0,
  'high_price': 10611000.0,
  'low_price': 10596000.0,
  'closing_price': 10611000.0,
  'acc_price': 59612254.02454,
  'acc_volume': 5.6232814,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:53:00',
  'opening_price': 10612000.0,
  'high_price': 10622000.0,
  'low_price': 10612000.0,
  'closing_price': 10622000.0,
  'acc_price': 50830798.21126,
  'acc_volume': 4.78835739,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:54:00',
  'opening_price': 10617000.0,
  'high_price': 10630000.0,
  'low_price': 10617000.0,
  'closing_price': 10630000.0,
  'acc_price': 82005173.84158,
  'acc_volume': 7.71635194,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:55:00',
  'opening_price': 10630000.0,
  'high_price': 10650000.0,
  'low_price': 10630000.0,
  'closing_price': 10650000.0,
  'acc_price': 99752483.10131,
  'acc_volume': 9.37410465,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:56:00',
  'opening_price': 10646000.0,
  'high_price': 10657000.0,
  'low_price': 10646000.0,
  'closing_price': 10646000.0,
  'acc_price': 328379382.72467,
  'acc_volume': 30.83367158,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:57:00',
  'opening_price': 10646000.0,
  'high_price': 10650000.0,
  'low_price': 10645000.0,
  'closing_price': 10647000.0,
  'acc_price': 51564466.13633,
  'acc_volume': 4.84241397,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:58:00',
  'opening_price': 10646000.0,
  'high_price': 10669000.0,
  'low_price': 10646000.0,
  'closing_price': 10669000.0,
  'acc_price': 197890470.89159,
  'acc_volume': 18.56679051,
  'kind': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T05:59:00',
  'opening_price': 10669000.0,
  'high_price': 10671000.0,
  'low_price': 10666000.0,
  'closing_price': 10670000.0,
  'acc_price': 106676249.34666,
  'acc_volume': 9.99976792,
  'kind': 0}
]

# %% [markdown]
# ### dummy_info_list로 DataFrame을 만들고 키값을 변경

# %%
import pandas as pd
total = pd.DataFrame(dummy_info_list)
total = total.rename(
  columns={
      "date_time": "Date",
      "opening_price": "Open",
      "high_price": "High",
      "low_price": "Low",
      "closing_price": "Close",
      "acc_volume": "Volume",
  }
)
total
# Out:
#     market                 Date        Open        High         Low  \
# 0  KRW-BTC  2020-04-30T05:50:00  10591000.0  10605000.0  10591000.0
# 1  KRW-BTC  2020-04-30T05:51:00  10608000.0  10611000.0  10596000.0
# 2  KRW-BTC  2020-04-30T05:52:00  10598000.0  10611000.0  10596000.0
# 3  KRW-BTC  2020-04-30T05:53:00  10612000.0  10622000.0  10612000.0
# 4  KRW-BTC  2020-04-30T05:54:00  10617000.0  10630000.0  10617000.0
# 5  KRW-BTC  2020-04-30T05:55:00  10630000.0  10650000.0  10630000.0
# 6  KRW-BTC  2020-04-30T05:56:00  10646000.0  10657000.0  10646000.0
# 7  KRW-BTC  2020-04-30T05:57:00  10646000.0  10650000.0  10645000.0
# 8  KRW-BTC  2020-04-30T05:58:00  10646000.0  10669000.0  10646000.0
# 9  KRW-BTC  2020-04-30T05:59:00  10669000.0  10671000.0  10666000.0
#
#         Close     acc_price     Volume  kind
# 0  10605000.0  1.163165e+08  10.972881     0
# 1  10598000.0  1.327499e+08  12.522345     0
# 2  10611000.0  5.961225e+07   5.623281     0
# ...

# %% [markdown]
# ### Data 컬럼을 인덱스로 설정하고 datetime 객체로 만들어준다

# %%
total = total.set_index("Date")
total.index = pd.to_datetime(total.index)
total
# Out:
#                       market        Open        High         Low       Close  \
# Date
# 2020-04-30 05:50:00  KRW-BTC  10591000.0  10605000.0  10591000.0  10605000.0
# 2020-04-30 05:51:00  KRW-BTC  10608000.0  10611000.0  10596000.0  10598000.0
# 2020-04-30 05:52:00  KRW-BTC  10598000.0  10611000.0  10596000.0  10611000.0
# 2020-04-30 05:53:00  KRW-BTC  10612000.0  10622000.0  10612000.0  10622000.0
# 2020-04-30 05:54:00  KRW-BTC  10617000.0  10630000.0  10617000.0  10630000.0
# 2020-04-30 05:55:00  KRW-BTC  10630000.0  10650000.0  10630000.0  10650000.0
# 2020-04-30 05:56:00  KRW-BTC  10646000.0  10657000.0  10646000.0  10646000.0
# 2020-04-30 05:57:00  KRW-BTC  10646000.0  10650000.0  10645000.0  10647000.0
# 2020-04-30 05:58:00  KRW-BTC  10646000.0  10669000.0  10646000.0  10669000.0
# 2020-04-30 05:59:00  KRW-BTC  10669000.0  10671000.0  10666000.0  10670000.0
#
#                         acc_price     Volume  kind
# Date
# 2020-04-30 05:50:00  1.163165e+08  10.972881     0
# ...

# %% [markdown]
# ### DataFrame을 이용해서 캔들그래프를 그린다

# %%
import mplfinance as mpf
mpf.plot(total, type="candle", volume=True, style="starsandstripes")

# %% [markdown]
# ### Test용 total list, 추가 그래프를 그리기 위한 데이터가 추가된 리스트

# %%
total_list = [{'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:05:00',
  'opening_price': 10563000.0,
  'high_price': 10571000.0,
  'low_price': 10553000.0,
  'closing_price': 10570000.0,
  'acc_price': 125016880.36179,
  'acc_volume': 11.83838866,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:06:00',
  'opening_price': 10569000.0,
  'high_price': 10569000.0,
  'low_price': 10525000.0,
  'closing_price': 10541000.0,
  'acc_price': 170233795.53858,
  'acc_volume': 16.13286781,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:07:00',
  'opening_price': 10543000.0,
  'high_price': 10554000.0,
  'low_price': 10525000.0,
  'closing_price': 10551000.0,
  'acc_price': 117197604.53511,
  'acc_volume': 11.12671815,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:08:00',
  'opening_price': 10544000.0,
  'high_price': 10571000.0,
  'low_price': 10542000.0,
  'closing_price': 10553000.0,
  'acc_price': 160541193.29183,
  'acc_volume': 15.21643098,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:09:00',
  'opening_price': 10553000.0,
  'high_price': 10571000.0,
  'low_price': 10553000.0,
  'closing_price': 10570000.0,
  'acc_price': 24123712.32792,
  'acc_volume': 2.28315364,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:10:00',
  'opening_price': 10570000.0,
  'high_price': 10583000.0,
  'low_price': 10561000.0,
  'closing_price': 10576000.0,
  'acc_price': 55884451.39599,
  'acc_volume': 5.28528135,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:11:00',
  'opening_price': 10584000.0,
  'high_price': 10668000.0,
  'low_price': 10584000.0,
  'closing_price': 10619000.0,
  'acc_price': 248089440.31111,
  'acc_volume': 23.380787,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:12:00',
  'opening_price': 10641000.0,
  'high_price': 10641000.0,
  'low_price': 10620000.0,
  'closing_price': 10627000.0,
  'acc_price': 106095669.19354,
  'acc_volume': 9.97880594,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:13:00',
  'opening_price': 10624000.0,
  'high_price': 10624000.0,
  'low_price': 10588000.0,
  'closing_price': 10611000.0,
  'acc_price': 79892387.53559,
  'acc_volume': 7.53610537,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:14:00',
  'opening_price': 10611000.0,
  'high_price': 10617000.0,
  'low_price': 10611000.0,
  'closing_price': 10612000.0,
  'acc_price': 31435566.052,
  'acc_volume': 2.96176369,
  'kind': 0,
  'return': 0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:15:00',
  'opening_price': 10617000.0,
  'high_price': 10640000.0,
  'low_price': 10616000.0,
  'closing_price': 10640000.0,
  'acc_price': 71021259.56352,
  'acc_volume': 6.67818262,
  'kind': 0,
  'buy': 10640000.0,
  'return': -0.221,
  'avr_price': 10640000.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:16:00',
  'opening_price': 10640000.0,
  'high_price': 10640000.0,
  'low_price': 10554000.0,
  'closing_price': 10574000.0,
  'acc_price': 213694042.37772,
  'acc_volume': 20.16705026,
  'kind': 0,
  'buy': 10574000.0,
  'return': 0.073,
  'avr_price': 10607000.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:17:00',
  'opening_price': 10574000.0,
  'high_price': 10624000.0,
  'low_price': 10574000.0,
  'closing_price': 10624000.0,
  'acc_price': 27553306.72052,
  'acc_volume': 2.60075435,
  'kind': 0,
  'buy': 10624000.0,
  'return': -0.204,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:18:00',
  'opening_price': 10595000.0,
  'high_price': 10614000.0,
  'low_price': 10595000.0,
  'closing_price': 10596000.0,
  'acc_price': 21217229.84691,
  'acc_volume': 1.99925902,
  'kind': 0,
  'return': -0.204,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:19:00',
  'opening_price': 10597000.0,
  'high_price': 10613000.0,
  'low_price': 10576000.0,
  'closing_price': 10576000.0,
  'acc_price': 78719024.01547,
  'acc_volume': 7.4309397,
  'kind': 0,
  'return': -0.39,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:20:00',
  'opening_price': 10590000.0,
  'high_price': 10595000.0,
  'low_price': 10584000.0,
  'closing_price': 10584000.0,
  'acc_price': 46789949.09722,
  'acc_volume': 4.41728984,
  'kind': 0,
  'return': -0.39,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:21:00',
  'opening_price': 10584000.0,
  'high_price': 10594000.0,
  'low_price': 10584000.0,
  'closing_price': 10587000.0,
  'acc_price': 12627442.26131,
  'acc_volume': 1.19234456,
  'kind': 0,
  'return': -0.288,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:22:00',
  'opening_price': 10587000.0,
  'high_price': 10594000.0,
  'low_price': 10587000.0,
  'closing_price': 10590000.0,
  'acc_price': 24121732.49702,
  'acc_volume': 2.27779416,
  'kind': 0,
  'sell': 10590000.0,
  'return': -0.239,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:23:00',
  'opening_price': 10590000.0,
  'high_price': 10596000.0,
  'low_price': 10588000.0,
  'closing_price': 10596000.0,
  'acc_price': 33316167.48592,
  'acc_volume': 3.14566627,
  'kind': 0,
  'sell': 10596000.0,
  'return': -0.259,
  'avr_price': 10612667.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:24:00',
  'opening_price': 10596000.0,
  'high_price': 10605000.0,
  'low_price': 10592000.0,
  'closing_price': 10595000.0,
  'acc_price': 37003507.91232,
  'acc_volume': 3.49285543,
  'kind': 0,
  'buy': 10595000.0,
  'return': -0.28,
  'avr_price': 10605532.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:25:00',
  'opening_price': 10595000.0,
  'high_price': 10605000.0,
  'low_price': 10592000.0,
  'closing_price': 10593000.0,
  'acc_price': 89250545.82747,
  'acc_volume': 8.42271859,
  'kind': 0,
  'buy': 10593000.0,
  'return': -0.284,
  'avr_price': 10601927.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:26:00',
  'opening_price': 10593000.0,
  'high_price': 10601000.0,
  'low_price': 10593000.0,
  'closing_price': 10594000.0,
  'acc_price': 29726922.48995,
  'acc_volume': 2.80622472,
  'kind': 0,
  'buy': 10594000.0,
  'return': -0.145,
  'avr_price': 10600156.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:27:00',
  'opening_price': 10594000.0,
  'high_price': 10610000.0,
  'low_price': 10594000.0,
  'closing_price': 10610000.0,
  'acc_price': 69240309.12415,
  'acc_volume': 6.53106483,
  'kind': 0,
  'return': -0.145,
  'avr_price': 10600156.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:28:00',
  'opening_price': 10610000.0,
  'high_price': 10610000.0,
  'low_price': 10593000.0,
  'closing_price': 10594000.0,
  'acc_price': 124335516.63124,
  'acc_volume': 11.72878474,
  'kind': 0,
  'sell': 10594000.0,
  'return': -0.224,
  'avr_price': 10600156.0},
 {'market': 'KRW-BTC',
  'date_time': '2020-04-30T06:29:00',
  'opening_price': 10595000.0,
  'high_price': 10608000.0,
  'low_price': 10595000.0,
  'closing_price': 10608000.0,
  'acc_price': 40680534.44281,
  'acc_volume': 3.83602971,
  'kind': 0,
  'return': -0.224,
  'avr_price': 10600156.0}]

# %% [markdown]
# ### dummy_info_list로 DataFrame을 만들고 키값을 변경

# %%
import pandas as pd
total = pd.DataFrame(total_list)
total = total.rename(
  columns={
      "date_time": "Date",
      "opening_price": "Open",
      "high_price": "High",
      "low_price": "Low",
      "closing_price": "Close",
      "acc_volume": "Volume",
  }
)
total
# Out:
#      market                 Date        Open        High         Low  \
# 0   KRW-BTC  2020-04-30T06:05:00  10563000.0  10571000.0  10553000.0
# 1   KRW-BTC  2020-04-30T06:06:00  10569000.0  10569000.0  10525000.0
# 2   KRW-BTC  2020-04-30T06:07:00  10543000.0  10554000.0  10525000.0
# 3   KRW-BTC  2020-04-30T06:08:00  10544000.0  10571000.0  10542000.0
# 4   KRW-BTC  2020-04-30T06:09:00  10553000.0  10571000.0  10553000.0
# 5   KRW-BTC  2020-04-30T06:10:00  10570000.0  10583000.0  10561000.0
# 6   KRW-BTC  2020-04-30T06:11:00  10584000.0  10668000.0  10584000.0
# 7   KRW-BTC  2020-04-30T06:12:00  10641000.0  10641000.0  10620000.0
# 8   KRW-BTC  2020-04-30T06:13:00  10624000.0  10624000.0  10588000.0
# 9   KRW-BTC  2020-04-30T06:14:00  10611000.0  10617000.0  10611000.0
# 10  KRW-BTC  2020-04-30T06:15:00  10617000.0  10640000.0  10616000.0
# 11  KRW-BTC  2020-04-30T06:16:00  10640000.0  10640000.0  10554000.0
# 12  KRW-BTC  2020-04-30T06:17:00  10574000.0  10624000.0  10574000.0
# ...

# %% [markdown]
# ### Data 컬럼을 인덱스로 설정하고 datetime 객체로 만들어준다

# %%
total = total.set_index("Date")
total.index = pd.to_datetime(total.index)
total
# Out:
#                       market        Open        High         Low       Close  \
# Date
# 2020-04-30 06:05:00  KRW-BTC  10563000.0  10571000.0  10553000.0  10570000.0
# 2020-04-30 06:06:00  KRW-BTC  10569000.0  10569000.0  10525000.0  10541000.0
# 2020-04-30 06:07:00  KRW-BTC  10543000.0  10554000.0  10525000.0  10551000.0
# 2020-04-30 06:08:00  KRW-BTC  10544000.0  10571000.0  10542000.0  10553000.0
# 2020-04-30 06:09:00  KRW-BTC  10553000.0  10571000.0  10553000.0  10570000.0
# 2020-04-30 06:10:00  KRW-BTC  10570000.0  10583000.0  10561000.0  10576000.0
# 2020-04-30 06:11:00  KRW-BTC  10584000.0  10668000.0  10584000.0  10619000.0
# 2020-04-30 06:12:00  KRW-BTC  10641000.0  10641000.0  10620000.0  10627000.0
# 2020-04-30 06:13:00  KRW-BTC  10624000.0  10624000.0  10588000.0  10611000.0
# 2020-04-30 06:14:00  KRW-BTC  10611000.0  10617000.0  10611000.0  10612000.0
# 2020-04-30 06:15:00  KRW-BTC  10617000.0  10640000.0  10616000.0  10640000.0
# ...

# %% [markdown]
# ### DataFrame을 이용해서 캔들그래프를 그린다

# %%
import mplfinance as mpf
mpf.plot(total, type="candle", volume=True, style="starsandstripes")

# %% [markdown]
# ### 추가 그래프가 포함된 그래프를 그린다

# %%
apds = [
    mpf.make_addplot(total["buy"], type="scatter", markersize=100, marker="^"),
    mpf.make_addplot(total["sell"], type="scatter", markersize=100, marker="v"),
    mpf.make_addplot(total["avr_price"]),
    mpf.make_addplot((total["return"]), panel=1, color="g", secondary_y=True)
]

mpf.plot(
    total,
    type="candle",
    volume=True,
    addplot=apds,
    style="starsandstripes",
)
